# %% [markdown]
# ______________________________________________________________________________________________________________
# # curently doing
# 1. Dsa
# 2. react
# 3. tailwindcss
# 4. fastapi
# 5. DBMS
# 6. Networking
# 7.
#
# # Main
# 1. DSA
# 2. FUll stack
# 3. Networking
#
# # Focus on
# 1. DSA
# 2. SKILL            -> full_stack, Cloud, AI/Ml
# 3. Project          -> Deploy an AI full stack application.
#
#
#
# # Order for project
# 1. Learn -> react,fastapi,Image classifier.(from Internship), Cloud.
# 2.
# ______________________________________________________________________________________________________________

# %% [markdown]
# ______________________________________________________________________________________________________________
# # Time table
# 1. DSA          -> Morning before tiffin. And any other time that is sutable. In that time only solve. Dont watch tutorials.
# 2. Skills       -> reamining free time.
# 3. Project      -> Parallely with skills.
#
#
# ______________________________________________________________________________________________________________
