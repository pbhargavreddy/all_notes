# %% [markdown]
# 1. For bold use ** -> **Bold**
# 2. For italic ude _ -> _italic_
# 3. For strickthrough use  \~~ ->  ~~strike~~
# 4. For line break double space or "br" for line break<br>
# 5. use # for heading ## for subheading and ### soon.
# 6. Use ``` for commenting
# 7. to ignore any reserved symbol use \\

# %% [markdown]
# ~~~
#     1. Use tags like <u> <b> <i> <img> etc
# ~~~
