# %% [markdown]
# For bold use ** -> **Bold**
# For italic ude _ -> _italic_
# For strickthrough udse ~~ -> ~~strike~~
# For line break double space or "br" for line break<br>
# use /# for heading /## for subheading and /### too
# # heading
# Use ``` for commenting
